# %%
#importing libraries
import matplotlib.pyplot as plt
import plotly.plotly as py
import pandas as pd
import numpy as np
import plotly
import quandl


from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from pandas_datareader import data as pdr

# Set plotly offline
init_notebook_mode(connected=True)

# Set matplotlib style
plt.style.use('seaborn')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import cufflinks as cf
cf.go_offline()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
# download quotes
tickers = ['TLT', 'SPY']
Quotes = pd.DataFrame()
Start ='2000-12-15'
End = "2017-03-20"

for ticker in tickers:
    locals()[ticker] = pdr.get_data_yahoo(ticker, start=Start, end=End)
    locals()[ticker]['adj_ratio'] = locals()[ticker]['Adj Close'] / locals()[ticker]['Close']
    locals()[ticker]['adj_open']  = locals()[ticker]['Open']  * locals()[ticker]['adj_ratio']
    locals()[ticker]['adj_high']  = locals()[ticker]['High']  * locals()[ticker]['adj_ratio']
    locals()[ticker]['adj_low']   = locals()[ticker]['Low']   * locals()[ticker]['adj_ratio']
    locals()[ticker]['adj_close'] = locals()[ticker]['Close'] * locals()[ticker]['adj_ratio']
    locals()[ticker] = locals()[ticker].iloc[:, -4:]

# %%
SPY.iplot()
# Out:
# <div id="e79f6799-980c-47c4-8811-9980cce584fa" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e79f6799-980c-47c4-8811-9980cce584fa", [{"type": "scatter", "x": ["2000-12-15", "2000-12-18", "2000-12-19", "2000-12-20", "2000-12-21", "2000-12-22", "2000-12-26", "2000-12-27", "2000-12-28", "2000-12-29", "2001-01-02", "2001-01-03", "2001-01-04", "2001-01-05", "2001-01-08", "2001-01-09", "2001-01-10", "2001-01-11", "2001-01-12", "2001-01-16", "2001-01-17", "2001-01-18", "2001-01-19", "2001-01-22", "2001-01-23", "2001-01-24", "2001-01-25", "2001-01-26", "2001-01-29", "2001-01-30", "2001-01-31", "2001-02-01", "2001-02-02", "2001-02-05", "2001-02-06", "2001-02-07", "2001-02-08", "2001-02-09", "2001-02-12", "2001-02-13", "2001-02-14", "2001-02-15", "2001-02-16", "2001-02-20", "2001-02-21", "2001-02-22", "200
# ...
